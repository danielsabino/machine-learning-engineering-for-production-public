# %% [markdown]
# <a href="https://colab.research.google.com/github/danielsabino/machine-learning-engineering-for-production-public/blob/main/semana02/03/codigo/%5Bnotebook%5Dcv_w02_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classificação de Imagens (faces)

# %% [markdown]
# ## Base de Dados
#
# Base de Dados: [Labeled Faces in the Wild (LFW)](http://vis-www.cs.umass.edu/lfw/index.html). A base de dados LFW é um benchmark público para verificação de faces, também conhecido como *pair matching*.
#
# Vale salientar que esse conjunto de dados foi publicado para ajudar a comunidade acadêmica a desenvolver avanços na verificação facial e não fornece os requisitos para ser considerada um ponto de validação para aplicações comerciais.
#
# A LFW contém mais de 13.000 imagens de faces coletadas na internet. Cada face está rotulada com o nome da pessoa. Para 1680 pessoas, existe duas ou mais fotos distintas no conjunto de dados.

# %% [markdown]
# # Regressão Logística
#
# A regressão logística é uma técnica estatística que tem como objetivo básico realizar a predição de valores categóricos a partir de um conjunto de dados contínuos. Sem dúvida, é um modelos mais simples de serem construídos, mas que apresenta resultados satisfatórios em muitas situações.
#
# Mais informações podem ser encontradas [aqui](https://pt.wikipedia.org/wiki/Regressão_log%C3%ADstica).

# %%
# importar os pacotes necessários
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
import numpy as np
import imutils
import cv2
import sklearn
from sklearn.model_selection import train_test_split
from google.colab.patches import cv2_imshow

# %%
# adquirir um pequeno subconjunto da base Labeled Faces in the Wild 
print("[INFO] obtendo dados...")
dataset = datasets.fetch_lfw_people(min_faces_per_person=70, funneled=True, resize=0.5)
# Out:
# [INFO] obtendo dados...

# %%
# construir  o conjunto de treinamento e teste.
(trainData, testData, trainLabels, testLabels) = train_test_split(dataset.data, dataset.target,
	test_size=0.25, random_state=42)

# %% [markdown]
# ## Treinar o classificador
#
# Vamos treinar um modelo de regressão logística para realizar a classificação de faces. Como não estamos interessados aqui em realizar a otimização dos hiperparâmetros do modelo, não vamos fazer uso do conjunto de validação, então, o modelo será treinado com o conjunto de treino e as medidas de desempenho serão avaliadas diretamente com a função `model.predict` no conjunto de testes.

# %%
# treinar o modelo e exibir o relatório de classificação
print("[INFO] treinando modelo...")
model = LogisticRegression()
model.fit(trainData, trainLabels)
print(classification_report(testLabels, model.predict(testData),
	target_names=dataset.target_names))
# Out:
# [INFO] treinando modelo...
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.47      0.54      0.50        13
#      Colin Powell       0.87      0.87      0.87        60
#   Donald Rumsfeld       0.61      0.63      0.62        27
#     George W Bush       0.91      0.88      0.90       146
# Gerhard Schroeder       0.63      0.76      0.69        25
#       Hugo Chavez       0.64      0.47      0.54        15
#        Tony Blair       0.76      0.81      0.78        36
#
#          accuracy                           0.80       322
#         macro avg       0.70      0.71      0.70       322
#      weighted avg       0.81      0.80      0.81       322
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %% [markdown]
# ## Testando classificador manualmente
#
# Para ter uma noção melhor do que significa o desempenho mostrada por meio do relatório anterior, vamos fazer a classificação de algumas imagens aleatórias presentes no conjunto de testes e mostrar as imagens para verificação manual.

# %%
# loop em algumas imagens aleatórias
for i in list(map(int, np.random.randint(0, high=testLabels.shape[0], size=(10,)))):
	# pega a imagem e o nome
	image = testData[i].reshape((62, 47))
	name = dataset.target_names[testLabels[i]]

  # redimensiona para uma melhor visualização
	image = imutils.resize(image.astype("uint8"), width=image.shape[1] * 3, inter=cv2.INTER_CUBIC)
	
  # classifica a imagem utilizando o modelo treinado
	prediction = model.predict(testData[i].reshape(1, -1))[0]
	prediction = dataset.target_names[prediction]
	print("[PREDIÇÃO] predito: {}, real: {}".format(prediction, name))
	cv2_imshow(image)
# Out:
# [PREDIÇÃO] predito: George W Bush, real: Tony Blair
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC8191D0>
# [PREDIÇÃO] predito: George W Bush, real: George W Bush
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC819F90>
# [PREDIÇÃO] predito: Tony Blair, real: Tony Blair
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC8191D0>
# [PREDIÇÃO] predito: Gerhard Schroeder, real: Hugo Chavez
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC819F90>
# [PREDIÇÃO] predito: Ariel Sharon, real: Ariel Sharon
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC8191D0>
# [PREDIÇÃO] predito: George W Bush, real: George W Bush
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC819F90>
# [PREDIÇÃO] predito: George W Bush, real: Colin Powell
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC8191D0>
# [PREDIÇÃO] predito: George W Bush, real: George W Bush
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC819F90>
# [PREDIÇÃO] predito: George W Bush, real: George W Bush
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC819850>
# [PREDIÇÃO] predito: Tony Blair, real: George W Bush
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC819610>

# %% [markdown]
# # Support Vector Machine
#
# As Máquinas de Vetores de Suporte são técnicas supervisionadas para construir modelos de classificação e regressão. As SVMs constituem uma das mais robustas técnicas para realizar predição.
#
# A ideia básica da técnica consiste em mapear os exemplos de entrada em pontos no espaço de maneira a maximizar a distância entre as categorias. Isso é alcançado, normalmente, utilizando uma função de *kernel* para realizar o mapeamento. Mais informações sobre a técnica podem ser vistas [aqui](https://en.wikipedia.org/wiki/Support-vector_machine).
#
# Para demonstrar a capacidade do SVM, devemos analisar quais as limitações de uma classificação linear. Vamos simular dados de uma operação XOR, que não pode ser separada somente com uma linha reta e treinar um modelo SVM com kernel linear para verificar o resultado.
#
# A função `SVC` do pacote `sklearn.svm` faz o papel do algoritmo para treinamento do classificador SVM.

# %%
from sklearn.svm import SVC

# gerar os dados XOR
tl = np.random.uniform(size=(100, 2)) + np.array([-2.0, 2.0])
tr = np.random.uniform(size=(100, 2)) + np.array([2.0, 2.0])
br = np.random.uniform(size=(100, 2)) + np.array([2.0, -2.0])
bl = np.random.uniform(size=(100, 2)) + np.array([-2.0, -2.0])
X = np.vstack([tl, tr, br, bl])
y = np.hstack([[1] * len(tl), [-1] * len(tr), [1] * len(br), [-1] * len(bl)])

# construir os conjunto de treinamento e teste
(trainData, testData, trainLabels, testLabels) = train_test_split(X, y, test_size=0.25,
	random_state=42)

# %% [markdown]
# ## Kernel Linear
#
# Construindo um classificador com kernel linear.

# %%
# treinar usando o SVM com kernel linear
print("[RESULTADOS] SVM com kernel linear")
model = SVC(kernel="linear")
model.fit(trainData, trainLabels)

# avaliar os resultados
print(classification_report(testLabels, model.predict(testData)))
# Out:
# [RESULTADOS] SVM com kernel linear
#               precision    recall  f1-score   support
#
#           -1       0.59      1.00      0.74        44
#            1       1.00      0.45      0.62        56
#
#     accuracy                           0.69       100
#    macro avg       0.79      0.72      0.68       100
# weighted avg       0.82      0.69      0.67       100

# %% [markdown]
# ## Kernel Polinomial
#
# Foi possível notar que, mesmo em um problema simples, mas que possui uma separação não-linear, o SVM com kernel linear não conseguiu encontrar o hiperplano de separação ideal e realizar a classificação corretamente.
#
# Vamos então, trabalhar com um kernel não-linar, como o polinomial, cuja transformação nos dados pode permitir que o hiperplano de separação seja suficiente para dividir os dados corretamente.

# %%
# treinar SVM usando kernel polinomial
print("[RESULTADOS] SVM com kernel polinomial.")
model = SVC(kernel="poly", degree=2, coef0=1)
model.fit(trainData, trainLabels)

# exibindo os resultados
print(classification_report(testLabels, model.predict(testData)))
# Out:
# [RESULTADOS] SVM com kernel polinomial.
#               precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00        44
#            1       1.00      1.00      1.00        56
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100

# %% [markdown]
# Nota-se pelos resultados, portanto, que uma transformação polinomial foi suficiente para levar os dados para um novo espaço de características, cuja separação pode ser feita por um hiperplano.

# %% [markdown]
# Vamos mostrar agora o SVM no mesmo problema anterior de classificação de faces.

# %%
# adquirir um pequeno subconjunto da base Labeled Faces in the Wild 
print("[INFO] obtendo dados...")
dataset = datasets.fetch_lfw_people(min_faces_per_person=70, funneled=True, resize=0.5)
# Out:
# [INFO] obtendo dados...

# %%
# construir  o conjunto de treinamento e teste.
(trainData, testData, trainLabels, testLabels) = train_test_split(dataset.data, dataset.target,
	test_size=0.25, random_state=42)

# %%
print("[INFO] treinando modelo...")
model = SVC(kernel="rbf")
model.fit(trainData, trainLabels)
print(classification_report(testLabels, model.predict(testData),
	target_names=dataset.target_names))
# Out:
# [INFO] treinando modelo...
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       1.00      0.46      0.63        13
#      Colin Powell       0.79      0.80      0.79        60
#   Donald Rumsfeld       0.82      0.52      0.64        27
#     George W Bush       0.73      0.97      0.83       146
# Gerhard Schroeder       0.80      0.48      0.60        25
#       Hugo Chavez       0.83      0.33      0.48        15
#        Tony Blair       0.86      0.53      0.66        36
#
#          accuracy                           0.76       322
#         macro avg       0.83      0.58      0.66       322
#      weighted avg       0.78      0.76      0.75       322

# %%
# loop em algumas imagens aleatórias
for i in list(map(int, np.random.randint(0, high=testLabels.shape[0], size=(10,)))):
	# pega a imagem e o nome
	image = testData[i].reshape((62, 47))
	name = dataset.target_names[testLabels[i]]

  # redimensiona para uma melhor visualização
	image = imutils.resize(image.astype("uint8"), width=image.shape[1] * 3, inter=cv2.INTER_CUBIC)
	
  # classifica a imagem utilizando o modelo treinado
	prediction = model.predict(testData[i].reshape(1, -1))[0]
	prediction = dataset.target_names[prediction]
	print("[PREDIÇÃO] predito: {}, real: {}".format(prediction, name))
	cv2_imshow(image)
# Out:
# [PREDIÇÃO] predito: George W Bush, real: Colin Powell
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC8E0E50>
# [PREDIÇÃO] predito: George W Bush, real: George W Bush
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9B7E6F090>
# [PREDIÇÃO] predito: Colin Powell, real: Ariel Sharon
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC7F0750>
# [PREDIÇÃO] predito: Tony Blair, real: Gerhard Schroeder
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9ACE8E250>
# [PREDIÇÃO] predito: Colin Powell, real: Colin Powell
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC8E0310>
# [PREDIÇÃO] predito: Colin Powell, real: Colin Powell
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC7F0750>
# [PREDIÇÃO] predito: George W Bush, real: George W Bush
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9B7E6F090>
# [PREDIÇÃO] predito: George W Bush, real: George W Bush
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC781FD0>
# [PREDIÇÃO] predito: Colin Powell, real: Colin Powell
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9ACE8E250>
# [PREDIÇÃO] predito: Gerhard Schroeder, real: Gerhard Schroeder
# <PIL.Image.Image image mode=L size=141x186 at 0x7FA9AC8E0310>

# %% [markdown]
# # Classificação de Imagens (cenários)
#
# Para diversificar os exemplos de classificação de imagens, vamos partir para o problema de categorização de cenários. Nesse caso, queremos distinguir entre tipos de locais diferentes onde imagens foram capturadas. Por exemplo, queremos organizar fotos entre imagens tiradas na natureza ou em ambientes urbanos.
#
# Vamos também trabalhar com outros classificadores: as árvores de decisão.

# %% [markdown]
# # Árvores de Decisão
#
# As árvores de decisão são ferramentas para construir modelos que ajudam na tomada de decisão e possibilitam quantificar a chance de um determinado evento ocorrer.
#
# Uma árvore de decisão é um estrutura na qual os nós internos representam *testes* nos atributos das instâncias de uma base de dados, cada ramificação representa o resultado desse teste e cada folha representa um rótulo de classe. Uma característica marcante dessa técnica é a possibilidade de extrair regras de classificação. Para isso, basta percorrer o caminho da raiz até uma das folhas verificando os testes feitos. Uma explicação mais detalhada das árvores de decisão podem ser encontadas [aqui](https://en.wikipedia.org/wiki/Decision_tree).
#
# Vamos desmonstar um novo exemplo de classificação de imagens, onde o nosso objetivo é distinguir entre diferentes cenários.
#
# Nesse caso, para uma classificação mais robusta, não vamos utilizar as imagens diretamente, mas sim extrair características delas para utilizar como features de entrada para o classificador.
#
# O pacote `mahotas` traz alguns desses extratores de features. Aqui, para fins de exemplificação, vamos utilizar o *haralick* (`mahotas.features.haralick`).
#
# O primeiro passo, então, é instalar o pacote no ambiente do Colab.

# %%
# !pip install numpy --upgrade
# !pip install mahotas
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.5)
# Requirement already satisfied: mahotas in /usr/local/lib/python3.7/dist-packages (1.4.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mahotas) (1.21.5)

# %% [markdown]
# Após isso, vamos importar os pacotes e construir uma função para extrair as features das imagens. A construção da função não é algo obrigatório, mas vai facilitar nossa vida na hora de escrever o restante do código.

# %%
from sklearn.tree import DecisionTreeClassifier
import mahotas
#import mahotas.features
import os

# função que extrai as características da imagem
def describe(image):
	# extrai a média e desvio padrão de cada canal do espaço HSV.
	(means, stds) = cv2.meanStdDev(cv2.cvtColor(image, cv2.COLOR_BGR2HSV))
	colorStats = np.concatenate([means, stds]).flatten()
  # extrai Haralick texture features
	gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
	haralick = mahotas.features.haralick(gray).mean(axis=0)
  # retorna um vetor formado por estatísticas básicas e das Haralick texture features
	return np.hstack([colorStats, haralick])

# %% [markdown]
# ## Construindo Conjunto de Dados
#
# Vamos construir nosso dadataset a partir do conjunto de dados 4scenes. Esse conjunto de dados possui imagens de quatro tipos de cenários:
# - coasts (praia),
# - forests (florestas),
# - highways (estradas) e
# - streets (ruas urbanas).
#
# A ideia aqui é construir um classificador que possa distinguir entre esses quatro tipos de cenário tendo uma imagem como entrada.
#
# Note que vamos estruturar uma base de dados a partir da extração de características de cada imagem do conjunto de dados original. Para cada imagem, haverá um vetor com as características extraídas a partir do extrator *haralick*.

# %%
# baixando o conjunto de dados
# !rm *.zip.*
# !wget 'https://github.com/danielsabino/ppgti3007_cv_2021_2/raw/main/semana02/03/codigo/4scenes.zip'
# !ls -l
# Out:
# rm: cannot remove '*.zip.*': No such file or directory
# --2022-02-01 14:21:29--  https://github.com/danielsabino/ppgti3007_cv_2021_2/raw/main/semana02/03/codigo/4scenes.zip
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/danielsabino/ppgti3007_cv_2021_2/main/semana02/03/codigo/4scenes.zip [following]
# --2022-02-01 14:21:29--  https://raw.githubusercontent.com/danielsabino/ppgti3007_cv_2021_2/main/semana02/03/codigo/4scenes.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54187202 (52M) [application/zip]
# Saving to: ‘4scenes.zip’
#
# 4scenes.zip         100%[===================>]  51.68M   304MB/s    in 0.2s
#
# 2022-02-01 14:21:29 (304 MB/s) - ‘4scenes.zip’ saved [54187202/54187202]
#
# total 52924
# -rw-r--r-- 1 root root 54187202 Feb  1 14:21 4scenes.zip
# drwxr-xr-x 1 root root     4096 Jan  7 14:33 sample_data

# %%
# descompactando o conjunto de dados
# !unzip '/content/4scenes.zip'
# Out:
# Archive:  /content/4scenes.zip
#    creating: 4scenes/
#   inflating: 4scenes/highway_gre141.jpg
#   inflating: 4scenes/highway_bost389.jpg
#   inflating: 4scenes/highway_gre155.jpg
#   inflating: 4scenes/coast_natu641.jpg
#   inflating: 4scenes/forest_land314.jpg
#   inflating: 4scenes/street_street61.jpg
#   inflating: 4scenes/forest_nat449.jpg
#   inflating: 4scenes/forest_cdmc451.jpg
#   inflating: 4scenes/street_hexp29.jpg
#   inflating: 4scenes/highway_bost148.jpg
#   inflating: 4scenes/forest_land102.jpg
#   inflating: 4scenes/highway_bost160.jpg
#   inflating: 4scenes/highway_bost174.jpg
#   inflating: 4scenes/coast_n203030.jpg
#   inflating: 4scenes/street_bost50.jpg
#   inflating: 4scenes/forest_nat717.jpg
#   inflating: 4scenes/forest_cdmc280.jpg
#   inflating: 4scenes/street_bost137.jpg
#   inflating: 4scenes/highway_urb710.jpg
#   inflating: 4scenes/forest_natu308.jpg
#   inflating: 4scenes/coast_land113.jpg
#   inflating: 4scenes/coast_natu912.jpg
#   inflating: 4scenes/street_par97.jpg
#   inflating: 4scenes/coast_n291022.jpg
#   inflating: 4scenes/forest_natu863.jpg
#   inflating: 4scenes/street_par192.jpg
#   inflating: 4scenes/street_par83.jpg
#   inflating: 4scenes/coast_land339.jpg
#   inflating: 4scenes/street_par151.jpg
#   inflating: 4scenes/street_par54.jpg
#   inflating: 4scenes/forest_text63.jpg
#   inflating: 4scenes/coast_cdmc871.jpg
#   inflating: 4scenes/street_par68.jpg
#   inflating: 4scenes/street_par178.jpg
#   inflating: 4scenes/street_par69.jpg
#   inflating: 4scenes/forest_nat266.jpg
#   inflating: 4scenes/coast_nat700.jpg
#   inflating: 4scenes/street_par150.jpg
#   inflating: 4scenes/forest_for67.jpg
#   inflating: 4scenes/street_artc14.jpg
#   inflating: 4scenes/coast_land112.jpg
#   inflating: 4scenes/street_bost136.jpg
#   inflating: 4scenes/forest_nat1253.jpg
#   inflating: 4scenes/forest_land64.jpg
#   inflating: 4scenes/forest_cdmc281.jpg
#   inflating: 4scenes/street_art838.jpg
#   inflating: 4scenes/street_bost45.jpg
#   inflating: 4scenes/forest_land922.jpg
#   inflating: 4scenes/street_art757.jpg
#   inflating: 4scenes/highway_bost175.jpg
#   inflating: 4scenes/highway_bost161.jpg
#   inflating: 4scenes/highway_land464.jpg
#   inflating: 4scenes/highway_bost149.jpg
#   inflating: 4scenes/coast_nat462.jpg
#   inflating: 4scenes/forest_nat851.jpg
#   inflating: 4scenes/street_hexp28.jpg
#   inflating: 4scenes/street_art970.jpg
#   inflating: 4scenes/coast_nat890.jpg
#   inflating: 4scenes/street_par1.jpg
#   inflating: 4scenes/forest_nat312.jpg
#   inflating: 4scenes/coast_land258.jpg
#   inflating: 4scenes/highway_a836030.jpg
#   inflating: 4scenes/street_street48.jpg
#   inflating: 4scenes/forest_nat1131.jpg
#   inflating: 4scenes/highway_gre140.jpg
#   inflating: 4scenes/coast_n243011.jpg
#   inflating: 4scenes/forest_text124.jpg
#   inflating: 4scenes/forest_nat1127.jpg
#   inflating: 4scenes/forest_nat310.jpg
#   inflating: 4scenes/coast_n708024.jpg
#   inflating: 4scenes/highway_urb471.jpg
#   inflating: 4scenes/street_par3.jpg
#   inflating: 4scenes/coast_natu130.jpg
#   inflating: 4scenes/street_street62.jpg
#   inflating: 4scenes/forest_nat338.jpg
#   inflating: 4scenes/coast_natu642.jpg
#   inflating: 4scenes/coast_cdmc906.jpg
#   inflating: 4scenes/forest_land854.jpg
#   inflating: 4scenes/highway_art328.jpg
#   inflating: 4scenes/highway_gre426.jpg
#   inflating: 4scenes/coast_natu468.jpg
#   inflating: 4scenes/highway_bost177.jpg
#   inflating: 4scenes/highway_bost163.jpg
#   inflating: 4scenes/coast_n295051.jpg
#   inflating: 4scenes/coast_sun57.jpg
#   inflating: 4scenes/street_boston360.jpg
#   inflating: 4scenes/highway_urb713.jpg
#   inflating: 4scenes/forest_cdmc283.jpg
#   inflating: 4scenes/street_par185.jpg
#   inflating: 4scenes/street_par80.jpg
#   inflating: 4scenes/forest_for148.jpg
#   inflating: 4scenes/forest_for65.jpg
#   inflating: 4scenes/street_par94.jpg
#   inflating: 4scenes/forest_natu860.jpg
#   inflating: 4scenes/forest_urb767.jpg
#   inflating: 4scenes/coast_natu911.jpg
#   inflating: 4scenes/forest_natu848.jpg
#   inflating: 4scenes/street_art379.jpg
#   inflating: 4scenes/highway_art1674.jpg
#   inflating: 4scenes/street_par146.jpg
#   inflating: 4scenes/street_par152.jpg
#   inflating: 4scenes/coast_cdmc866.jpg
#   inflating: 4scenes/street_urb805.jpg
#   inflating: 4scenes/forest_text48.jpg
#   inflating: 4scenes/street_art1030.jpg
#   inflating: 4scenes/coast_cdmc873.jpg
#   inflating: 4scenes/forest_text49.jpg
#   inflating: 4scenes/street_par153.jpg
#   inflating: 4scenes/forest_text75.jpg
#   inflating: 4scenes/street_par42.jpg
#   inflating: 4scenes/street_hexp4.jpg
#   inflating: 4scenes/coast_natu938.jpg
#   inflating: 4scenes/forest_for58.jpg
#   inflating: 4scenes/coast_n291008.jpg
#   inflating: 4scenes/street_par95.jpg
#   inflating: 4scenes/forest_for149.jpg
#   inflating: 4scenes/street_par81.jpg
#   inflating: 4scenes/forest_natu322.jpg
#   inflating: 4scenes/coast_land111.jpg
#   inflating: 4scenes/street_bost121.jpg
#   inflating: 4scenes/forest_cdmc282.jpg
#   inflating: 4scenes/forest_nat715.jpg
#   inflating: 4scenes/street_art1583.jpg
#   inflating: 4scenes/street_bost46.jpg
#   inflating: 4scenes/coast_n122078.jpg
#   inflating: 4scenes/coast_sun56.jpg
#   inflating: 4scenes/forest_cdmc533.jpg
#   inflating: 4scenes/coast_sun42.jpg
#   inflating: 4scenes/coast_n203032.jpg
#   inflating: 4scenes/highway_bost162.jpg
#   inflating: 4scenes/highway_bost176.jpg
#   inflating: 4scenes/highway_gre58.jpg
#   inflating: 4scenes/street_art768.jpg
#   inflating: 4scenes/coast_natu469.jpg
#   inflating: 4scenes/street_hexp17.jpg
#   inflating: 4scenes/forest_land869.jpg
#   inflating: 4scenes/coast_land924.jpg
#   inflating: 4scenes/coast_natu643.jpg
#   inflating: 4scenes/coast_natu131.jpg
#   inflating: 4scenes/highway_bost374.jpg
#   inflating: 4scenes/coast_nat893.jpg
#   inflating: 4scenes/coast_nat1043.jpg
#   inflating: 4scenes/coast_n672004.jpg
#   inflating: 4scenes/coast_cdmc1000.jpg
#   inflating: 4scenes/street_art1187.jpg
#   inflating: 4scenes/forest_text119.jpg
#   inflating: 4scenes/coast_nat850.jpg
#   inflating: 4scenes/highway_gre609.jpg
#   inflating: 4scenes/forest_natc52.jpg
#   inflating: 4scenes/coast_n672000.jpg
#   inflating: 4scenes/street_street98.jpg
#   inflating: 4scenes/highway_gre153.jpg
#   inflating: 4scenes/highway_art885.jpg
#   inflating: 4scenes/highway_gre147.jpg
#   inflating: 4scenes/coast_nat897.jpg
#   inflating: 4scenes/street_par6.jpg
#   inflating: 4scenes/highway_bost402.jpg
#   inflating: 4scenes/coast_land277.jpg
#   inflating: 4scenes/street_art546.jpg
#   inflating: 4scenes/forest_nat315.jpg
#   inflating: 4scenes/coast_nat1053.jpg
#   inflating: 4scenes/coast_nat667.jpg
#   inflating: 4scenes/forest_cdmc319.jpg
#   inflating: 4scenes/street_art793.jpg
#   inflating: 4scenes/forest_cdmc331.jpg
#   inflating: 4scenes/highway_bost172.jpg
#   inflating: 4scenes/highway_bost166.jpg
#   inflating: 4scenes/highway_gre48.jpg
#   inflating: 4scenes/forest_bost98.jpg
#   inflating: 4scenes/highway_land463.jpg
#   inflating: 4scenes/forest_cdmc494.jpg
#   inflating: 4scenes/coast_n295068.jpg
#   inflating: 4scenes/street_bost56.jpg
#   inflating: 4scenes/street_boston1.jpg
#   inflating: 4scenes/coast_nat288.jpg
#   inflating: 4scenes/coast_n203036.jpg
#   inflating: 4scenes/coast_land115.jpg
#   inflating: 4scenes/street_bost81.jpg
#   inflating: 4scenes/forest_natu440.jpg
#   inflating: 4scenes/coast_natu531.jpg
#   inflating: 4scenes/highway_urb716.jpg
#   inflating: 4scenes/forest_cdmc292.jpg
#   inflating: 4scenes/street_gre116.jpg
#   inflating: 4scenes/coast_land897.jpg
#   inflating: 4scenes/forest_nat1095.jpg
#   inflating: 4scenes/forest_natu871.jpg
#   inflating: 4scenes/coast_n291030.jpg
#   inflating: 4scenes/street_par85.jpg
#   inflating: 4scenes/forest_for60.jpg
#   inflating: 4scenes/coast_n291024.jpg
#   inflating: 4scenes/coast_nat908.jpg
#   inflating: 4scenes/street_par91.jpg
#   inflating: 4scenes/coast_nat707.jpg
#   inflating: 4scenes/street_par143.jpg
#   inflating: 4scenes/street_par52.jpg
#   inflating: 4scenes/forest_moun46.jpg
#   inflating: 4scenes/street_par156.jpg
#   inflating: 4scenes/forest_nat260.jpg
#   inflating: 4scenes/coast_land302.jpg
#   inflating: 4scenes/coast_cdmc862.jpg
#   inflating: 4scenes/coast_cdmc889.jpg
#   inflating: 4scenes/street_par90.jpg
#   inflating: 4scenes/street_par84.jpg
#   inflating: 4scenes/coast_cdmc123.jpg
#   inflating: 4scenes/forest_natu870.jpg
#   inflating: 4scenes/coast_natu901.jpg
#   inflating: 4scenes/coast_nat921.jpg
#   inflating: 4scenes/forest_cdmc293.jpg
#   inflating: 4scenes/forest_natu2.jpg
#   inflating: 4scenes/forest_natu441.jpg
#   inflating: 4scenes/coast_land100.jpg
#   inflating: 4scenes/coast_land114.jpg
#   inflating: 4scenes/coast_n203037.jpg
#   inflating: 4scenes/forest_cdmc278.jpg
#   inflating: 4scenes/street_art779.jpg
#   inflating: 4scenes/highway_art489.jpg
#   inflating: 4scenes/highway_bost167.jpg
#   inflating: 4scenes/street_gre27.jpg
#   inflating: 4scenes/highway_bost173.jpg
#   inflating: 4scenes/coast_n384038.jpg
#   inflating: 4scenes/forest_land850.jpg
#   inflating: 4scenes/street_art976.jpg
#   inflating: 4scenes/forest_cdmc318.jpg
#   inflating: 4scenes/street_hexp12.jpg
#   inflating: 4scenes/coast_nat1052.jpg
#   inflating: 4scenes/highway_bost403.jpg
#   inflating: 4scenes/forest_nat328.jpg
#   inflating: 4scenes/forest_natu723.jpg
#   inflating: 4scenes/coast_cdmc916.jpg
#   inflating: 4scenes/highway_art890.jpg
#   inflating: 4scenes/coast_n243003.jpg
#   inflating: 4scenes/coast_nat1091.jpg
#   inflating: 4scenes/coast_n672003.jpg
#   inflating: 4scenes/highway_bost398.jpg
#   inflating: 4scenes/highway_gre144.jpg
#   inflating: 4scenes/forest_text122.jpg
#   inflating: 4scenes/coast_cdmc900.jpg
#   inflating: 4scenes/street_par5.jpg
#   inflating: 4scenes/forest_nat470.jpg
#   inflating: 4scenes/highway_gre408.jpg
#   inflating: 4scenes/highway_gre420.jpg
#   inflating: 4scenes/forest_land852.jpg
#   inflating: 4scenes/forest_land107.jpg
#   inflating: 4scenes/highway_bost165.jpg
#   inflating: 4scenes/highway_bost171.jpg
#   inflating: 4scenes/highway_bost159.jpg
#   inflating: 4scenes/coast_nat472.jpg
#   inflating: 4scenes/coast_open13.jpg
#   inflating: 4scenes/coast_n735016.jpg
#   inflating: 4scenes/coast_n18001.jpg
#   inflating: 4scenes/coast_sun45.jpg
#   inflating: 4scenes/forest_natu325.jpg
#   inflating: 4scenes/forest_natu443.jpg
#   inflating: 4scenes/street_bost82.jpg
#   inflating: 4scenes/coast_n295080.jpg
#   inflating: 4scenes/street_gre115.jpg
#   inflating: 4scenes/highway_urb715.jpg
#   inflating: 4scenes/forest_cdmc291.jpg
#   inflating: 4scenes/street_hexp3.jpg
#   inflating: 4scenes/highway_n480001.jpg
#   inflating: 4scenes/forest_natu696.jpg
#   inflating: 4scenes/forest_for77.jpg
#   inflating: 4scenes/forest_natu866.jpg
#   inflating: 4scenes/street_par197.jpg
#   inflating: 4scenes/forest_natu28.jpg
#   inflating: 4scenes/street_par86.jpg
#   inflating: 4scenes/forest_for63.jpg
#   inflating: 4scenes/coast_cdmc860.jpg
#   inflating: 4scenes/forest_land503.jpg
#   inflating: 4scenes/street_par79.jpg
#   inflating: 4scenes/street_par154.jpg
#   inflating: 4scenes/coast_cdmc848.jpg
#   inflating: 4scenes/coast_natu718.jpg
#   inflating: 4scenes/street_par140.jpg
#   inflating: 4scenes/highway_art1673.jpg
#   inflating: 4scenes/coast_nat1125.jpg
#   inflating: 4scenes/street_par141.jpg
#   inflating: 4scenes/forest_nat263.jpg
#   inflating: 4scenes/coast_nat705.jpg
#   inflating: 4scenes/coast_nat711.jpg
#   inflating: 4scenes/street_par155.jpg
#   inflating: 4scenes/street_par78.jpg
#   inflating: 4scenes/coast_nat739.jpg
#   inflating: 4scenes/forest_natu898.jpg
#   inflating: 4scenes/street_par169.jpg
#   inflating: 4scenes/forest_natu29.jpg
#   inflating: 4scenes/street_par87.jpg
#   inflating: 4scenes/coast_n291032.jpg
#   inflating: 4scenes/forest_nat1097.jpg
#   inflating: 4scenes/street_par93.jpg
#   inflating: 4scenes/forest_natu15.jpg
#   inflating: 4scenes/street_gre114.jpg
#   inflating: 4scenes/forest_cdmc290.jpg
#   inflating: 4scenes/highway_urb714.jpg
#   inflating: 4scenes/street_urb382.jpg
#   inflating: 4scenes/forest_cdmc284.jpg
#   inflating: 4scenes/forest_nat1242.jpg
#   inflating: 4scenes/street_gre128.jpg
#   inflating: 4scenes/highway_gre541.jpg
#   inflating: 4scenes/coast_sun44.jpg
#   inflating: 4scenes/street_bost40.jpg
#   inflating: 4scenes/street_boston373.jpg
#   inflating: 4scenes/coast_sun8.jpg
#   inflating: 4scenes/highway_bost158.jpg
#   inflating: 4scenes/highway_bost170.jpg
#   inflating: 4scenes/highway_land449.jpg
#   inflating: 4scenes/highway_bost164.jpg
#   inflating: 4scenes/forest_cdmc333.jpg
#   inflating: 4scenes/highway_gre409.jpg
#   inflating: 4scenes/coast_n384013.jpg
#   inflating: 4scenes/coast_cdmc929.jpg
#   inflating: 4scenes/street_street59.jpg
#   inflating: 4scenes/coast_land261.jpg
#   inflating: 4scenes/coast_nat895.jpg
#   inflating: 4scenes/street_par4.jpg
#   inflating: 4scenes/forest_natu913.jpg
#   inflating: 4scenes/highway_gre145.jpg
#   inflating: 4scenes/street_urb722.jpg
#   inflating: 4scenes/highway_gre644.jpg
#   inflating: 4scenes/coast_natu811.jpg
#   inflating: 4scenes/highway_gre650.jpg
#   inflating: 4scenes/forest_nat1184.jpg
#   inflating: 4scenes/highway_gre678.jpg
#   inflating: 4scenes/forest_natc37.jpg
#   inflating: 4scenes/street_gre211.jpg
#   inflating: 4scenes/coast_nat602.jpg
#   inflating: 4scenes/coast_n708050.jpg
#   inflating: 4scenes/forest_bost100.jpg
#   inflating: 4scenes/highway_bost329.jpg
#   inflating: 4scenes/highway_bost301.jpg
#   inflating: 4scenes/highway_bost315.jpg
#   inflating: 4scenes/forest_land377.jpg
#   inflating: 4scenes/coast_land951.jpg
#   inflating: 4scenes/highway_natu787.jpg
#   inflating: 4scenes/forest_cdmc368.jpg
#   inflating: 4scenes/street_boston274.jpg
#   inflating: 4scenes/highway_gre485.jpg
#   inflating: 4scenes/street_boston61.jpg
#   inflating: 4scenes/highway_gre491.jpg
#   inflating: 4scenes/highway_art1204.jpg
#   inflating: 4scenes/coast_natu408.jpg
#   inflating: 4scenes/highway_natu778.jpg
#   inflating: 4scenes/coast_nat1208.jpg
#   inflating: 4scenes/street_urb332.jpg
#   inflating: 4scenes/highway_gre532.jpg
#   inflating: 4scenes/forest_natu425.jpg
#   inflating: 4scenes/coast_natu795.jpg
#   inflating: 4scenes/forest_natu72.jpg
#   inflating: 4scenes/forest_for114.jpg
#   inflating: 4scenes/forest_nat210.jpg
#   inflating: 4scenes/forest_nat1027.jpg
#   inflating: 4scenes/forest_natu169.jpg
#   inflating: 4scenes/forest_nat204.jpg
#   inflating: 4scenes/forest_nat1033.jpg
#   inflating: 4scenes/forest_land217.jpg
#   inflating: 4scenes/forest_text28.jpg
#   inflating: 4scenes/coast_land372.jpg
#   inflating: 4scenes/forest_nat239.jpg
#   inflating: 4scenes/forest_text29.jpg
#   inflating: 4scenes/coast_land367.jpg
#   inflating: 4scenes/street_par22.jpg
#   inflating: 4scenes/forest_nat205.jpg
#   inflating: 4scenes/forest_nat211.jpg
#   inflating: 4scenes/street_par36.jpg
#   inflating: 4scenes/forest_for38.jpg
#   inflating: 4scenes/forest_natu430.jpg
#   inflating: 4scenes/forest_natu424.jpg
#   inflating: 4scenes/coast_n203085.jpg
#   inflating: 4scenes/street_gre600.jpg
#   inflating: 4scenes/street_bost26.jpg
#   inflating: 4scenes/coast_open60.jpg
#   inflating: 4scenes/forest_nat946.jpg
#   inflating: 4scenes/coast_bea20.jpg
#   inflating: 4scenes/coast_sun22.jpg
#   inflating: 4scenes/forest_cdmc547.jpg
#   inflating: 4scenes/highway_gre533.jpg
#   inflating: 4scenes/highway_gre484.jpg
#   inflating: 4scenes/street_gre95.jpg
#   inflating: 4scenes/forest_land809.jpg
#   inflating: 4scenes/street_urb521.jpg
#   inflating: 4scenes/forest_land376.jpg
#   inflating: 4scenes/highway_bost314.jpg
#   inflating: 4scenes/highway_bost300.jpg
#   inflating: 4scenes/forest_nat359.jpg
#   inflating: 4scenes/forest_nat417.jpg
#   inflating: 4scenes/forest_bost101.jpg
#   inflating: 4scenes/forest_natu949.jpg
#   inflating: 4scenes/highway_gre651.jpg
#   inflating: 4scenes/highway_gre645.jpg
#   inflating: 4scenes/coast_natu804.jpg
#   inflating: 4scenes/forest_natu977.jpg
#   inflating: 4scenes/coast_bea5.jpg
#   inflating: 4scenes/forest_nat398.jpg
#   inflating: 4scenes/forest_nat373.jpg
#   inflating: 4scenes/forest_bost103.jpg
#   inflating: 4scenes/highway_art820.jpg
#   inflating: 4scenes/coast_nat167.jpg
#   inflating: 4scenes/highway_gre684.jpg
#   inflating: 4scenes/coast_nat601.jpg
#   inflating: 4scenes/forest_nat367.jpg
#   inflating: 4scenes/highway_bost316.jpg
#   inflating: 4scenes/highway_bost302.jpg
#   inflating: 4scenes/coast_land946.jpg
#   inflating: 4scenes/street_boston263.jpg
#   inflating: 4scenes/highway_gre479.jpg
#   inflating: 4scenes/highway_gre492.jpg
#   inflating: 4scenes/highway_gre525.jpg
#   inflating: 4scenes/coast_sun34.jpg
#   inflating: 4scenes/coast_open62.jpg
#   inflating: 4scenes/forest_nat763.jpg
#   inflating: 4scenes/highway_art773.jpg
#   inflating: 4scenes/street_urban954.jpg
#   inflating: 4scenes/highway_n480070.jpg
#   inflating: 4scenes/street_par125.jpg
#   inflating: 4scenes/street_par20.jpg
#   inflating: 4scenes/street_urb866.jpg
#   inflating: 4scenes/street_par119.jpg
#   inflating: 4scenes/coast_land371.jpg
#   inflating: 4scenes/street_urban997.jpg
#   inflating: 4scenes/highway_a866048.jpg
#   inflating: 4scenes/street_urban996.jpg
#   inflating: 4scenes/forest_land215.jpg
#   inflating: 4scenes/street_par118.jpg
#   inflating: 4scenes/coast_land370.jpg
#   inflating: 4scenes/forest_nat212.jpg
#   inflating: 4scenes/coast_n328001.jpg
#   inflating: 4scenes/street_par21.jpg
#   inflating: 4scenes/street_par124.jpg
#   inflating: 4scenes/coast_cdmc838.jpg
#   inflating: 4scenes/forest_for102.jpg
#   inflating: 4scenes/forest_for116.jpg
#   inflating: 4scenes/coast_n291057.jpg
#   inflating: 4scenes/street_gre159.jpg
#   inflating: 4scenes/highway_urb759.jpg
#   inflating: 4scenes/forest_land765.jpg
#   inflating: 4scenes/forest_natu396.jpg
#   inflating: 4scenes/coast_n295027.jpg
#   inflating: 4scenes/highway_gre530.jpg
#   inflating: 4scenes/highway_art558.jpg
#   inflating: 4scenes/coast_sun21.jpg
#   inflating: 4scenes/forest_art114.jpg
#   inflating: 4scenes/street_boston289.jpg
#   inflating: 4scenes/highway_gre493.jpg
#   inflating: 4scenes/highway_gre478.jpg
#   inflating: 4scenes/forest_cdmc430.jpg
#   inflating: 4scenes/street_urb244.jpg
#   inflating: 4scenes/highway_bost303.jpg
#   inflating: 4scenes/highway_bost317.jpg
#   inflating: 4scenes/forest_nat400.jpg
#   inflating: 4scenes/highway_gre685.jpg
#   inflating: 4scenes/forest_bost102.jpg
#   inflating: 4scenes/coast_nat172.jpg
#   inflating: 4scenes/coast_bea4.jpg
#   inflating: 4scenes/highway_gre646.jpg
#   inflating: 4scenes/coast_natu813.jpg
#   inflating: 4scenes/street_art1686.jpg
#   inflating: 4scenes/coast_natu817.jpg
#   inflating: 4scenes/highway_gre656.jpg
#   inflating: 4scenes/coast_n243061.jpg
#   inflating: 4scenes/highway_bost313.jpg
#   inflating: 4scenes/highway_bost307.jpg
#   inflating: 4scenes/coast_cdmc960.jpg
#   inflating: 4scenes/coast_cdmc948.jpg
#   inflating: 4scenes/street_boston272.jpg
#   inflating: 4scenes/forest_nat835.jpg
#   inflating: 4scenes/street_gre86.jpg
#   inflating: 4scenes/forest_cdmc352.jpg
#   inflating: 4scenes/forest_cdmc385.jpg
#   inflating: 4scenes/coast_n384099.jpg
#   inflating: 4scenes/street_boston306.jpg
#   inflating: 4scenes/coast_bea33.jpg
#   inflating: 4scenes/coast_n203069.jpg
#   inflating: 4scenes/coast_bea27.jpg
#   inflating: 4scenes/coast_sun31.jpg
#   inflating: 4scenes/forest_nat982.jpg
#   inflating: 4scenes/forest_natu423.jpg
#   inflating: 4scenes/coast_nat566.jpg
#   inflating: 4scenes/forest_for112.jpg
#   inflating: 4scenes/forest_for106.jpg
#   inflating: 4scenes/street_urban951.jpg
#   inflating: 4scenes/highway_bost298.jpg
#   inflating: 4scenes/forest_for17.jpg
#   inflating: 4scenes/coast_land374.jpg
#   inflating: 4scenes/coast_n603063.jpg
#   inflating: 4scenes/street_par120.jpg
#   inflating: 4scenes/street_urb693.jpg
#   inflating: 4scenes/coast_nat770.jpg
#   inflating: 4scenes/street_par134.jpg
#   inflating: 4scenes/coast_nat1150.jpg
#   inflating: 4scenes/coast_nat1151.jpg
#   inflating: 4scenes/forest_text13.jpg
#   inflating: 4scenes/forest_sclos11.jpg
#   inflating: 4scenes/forest_nat203.jpg
#   inflating: 4scenes/forest_natu634.jpg
#   inflating: 4scenes/street_par18.jpg
#   inflating: 4scenes/highway_bost299.jpg
#   inflating: 4scenes/coast_nat956.jpg
#   inflating: 4scenes/street_urban950.jpg
#   inflating: 4scenes/street_gre160.jpg
#   inflating: 4scenes/forest_land760.jpg
#   inflating: 4scenes/street_art861.jpg
#   inflating: 4scenes/coast_bea26.jpg
#   inflating: 4scenes/forest_nat798.jpg
#   inflating: 4scenes/coast_n199065.jpg
#   inflating: 4scenes/coast_nat605.jpg
#   inflating: 4scenes/highway_gre680.jpg
#   inflating: 4scenes/coast_natu619.jpg
#   inflating: 4scenes/coast_nat639.jpg
#   inflating: 4scenes/highway_bost306.jpg
#   inflating: 4scenes/coast_natu631.jpg
#   inflating: 4scenes/street_art256.jpg
#   inflating: 4scenes/highway_bost312.jpg
#   inflating: 4scenes/highway_gre125.jpg
#   inflating: 4scenes/coast_natu816.jpg
#   inflating: 4scenes/highway_gre657.jpg
#   inflating: 4scenes/coast_bea1.jpg
#   inflating: 4scenes/coast_bea3.jpg
#   inflating: 4scenes/coast_nat820.jpg
#   inflating: 4scenes/coast_n243062.jpg
#   inflating: 4scenes/coast_natu814.jpg
#   inflating: 4scenes/coast_cdmc988.jpg
#   inflating: 4scenes/highway_bost304.jpg
#   inflating: 4scenes/highway_bost310.jpg
#   inflating: 4scenes/forest_nat349.jpg
#   inflating: 4scenes/coast_cdmc977.jpg
#   inflating: 4scenes/street_gre214.jpg
#   inflating: 4scenes/forest_nat361.jpg
#   inflating: 4scenes/street_urb928.jpg
#   inflating: 4scenes/coast_gre637.jpg
#   inflating: 4scenes/street_gre91.jpg
#   inflating: 4scenes/street_boston271.jpg
#   inflating: 4scenes/coast_land954.jpg
#   inflating: 4scenes/forest_cdmc351.jpg
#   inflating: 4scenes/highway_gre480.jpg
#   inflating: 4scenes/street_urb294.jpg
#   inflating: 4scenes/coast_n199067.jpg
#   inflating: 4scenes/coast_bea24.jpg
#   inflating: 4scenes/highway_art563.jpg
#   inflating: 4scenes/highway_gre279.jpg
#   inflating: 4scenes/street_gre189.jpg
#   inflating: 4scenes/coast_bea30.jpg
#   inflating: 4scenes/highway_gre537.jpg
#   inflating: 4scenes/coast_sun32.jpg
#   inflating: 4scenes/street_boston339.jpg
#   inflating: 4scenes/street_street110.jpg
#   inflating: 4scenes/forest_for105.jpg
#   inflating: 4scenes/forest_for28.jpg
#   inflating: 4scenes/forest_text39.jpg
#   inflating: 4scenes/forest_text11.jpg
#   inflating: 4scenes/street_urb848.jpg
#   inflating: 4scenes/street_par123.jpg
#   inflating: 4scenes/forest_sclos13.jpg
#   inflating: 4scenes/coast_nat1146.jpg
#   inflating: 4scenes/street_par33.jpg
#   inflating: 4scenes/street_art1041.jpg
#   inflating: 4scenes/forest_text38.jpg
#   inflating: 4scenes/forest_nat228.jpg
#   inflating: 4scenes/forest_n18075.jpg
#   inflating: 4scenes/coast_natu975.jpg
#   inflating: 4scenes/forest_for15.jpg
#   inflating: 4scenes/forest_for110.jpg
#   inflating: 4scenes/coast_nat799.jpg
#   inflating: 4scenes/coast_natu791.jpg
#   inflating: 4scenes/coast_nat202.jpg
#   inflating: 4scenes/coast_sun27.jpg
#   inflating: 4scenes/forest_cdmc556.jpg
#   inflating: 4scenes/street_art862.jpg
#   inflating: 4scenes/highway_art238.jpg
#   inflating: 4scenes/coast_sun33.jpg
#   inflating: 4scenes/highway_gre536.jpg
#   inflating: 4scenes/highway_art576.jpg
#   inflating: 4scenes/coast_n199066.jpg
#   inflating: 4scenes/highway_gre481.jpg
#   inflating: 4scenes/forest_land159.jpg
#   inflating: 4scenes/forest_nat162.jpg
#   inflating: 4scenes/forest_cdmc344.jpg
#   inflating: 4scenes/street_boston270.jpg
#   inflating: 4scenes/coast_nat174.jpg
#   inflating: 4scenes/forest_nat360.jpg
#   inflating: 4scenes/highway_gre683.jpg
#   inflating: 4scenes/highway_bost311.jpg
#   inflating: 4scenes/coast_cdmc976.jpg
#   inflating: 4scenes/highway_bost305.jpg
#   inflating: 4scenes/coast_n243063.jpg
#   inflating: 4scenes/coast_cdmc989.jpg
#   inflating: 4scenes/coast_natu815.jpg
#   inflating: 4scenes/coast_natu829.jpg
#   inflating: 4scenes/forest_natu794.jpg
#   inflating: 4scenes/coast_bea2.jpg
#   inflating: 4scenes/coast_natu824.jpg
#   inflating: 4scenes/coast_nat186.jpg
#   inflating: 4scenes/coast_natu830.jpg
#   inflating: 4scenes/street_street3.jpg
#   inflating: 4scenes/highway_gre659.jpg
#   inflating: 4scenes/coast_natu818.jpg
#   inflating: 4scenes/coast_cdmc990.jpg
#   inflating: 4scenes/coast_nat810.jpg
#   inflating: 4scenes/highway_bost308.jpg
#   inflating: 4scenes/highway_bost320.jpg
#   inflating: 4scenes/coast_cdmc953.jpg
#   inflating: 4scenes/highway_bost334.jpg
#   inflating: 4scenes/forest_land801.jpg
#   inflating: 4scenes/forest_cdmc375.jpg
#   inflating: 4scenes/highway_gre467.jpg
#   inflating: 4scenes/highway_gre473.jpg
#   inflating: 4scenes/street_boston241.jpg
#   inflating: 4scenes/street_boston255.jpg
#   inflating: 4scenes/coast_nat1201.jpg
#   inflating: 4scenes/forest_nat147.jpg
#   inflating: 4scenes/street_boston68.jpg
#   inflating: 4scenes/street_gre76.jpg
#   inflating: 4scenes/highway_gre30.jpg
#   inflating: 4scenes/coast_n203066.jpg
#   inflating: 4scenes/highway_gre275.jpg
#   inflating: 4scenes/coast_sun16.jpg
#   inflating: 4scenes/coast_n446013.jpg
#   inflating: 4scenes/street_gre191.jpg
#   inflating: 4scenes/coast_bea14.jpg
#   inflating: 4scenes/coast_art294.jpg
#   inflating: 4scenes/coast_osun51.jpg
#   inflating: 4scenes/coast_land623.jpg
#   inflating: 4scenes/highway_bost297.jpg
#   inflating: 4scenes/forest_for121.jpg
#   inflating: 4scenes/street_urban976.jpg
#   inflating: 4scenes/street_par113.jpg
#   inflating: 4scenes/street_par16.jpg
#   inflating: 4scenes/coast_n328036.jpg
#   inflating: 4scenes/coast_nat1177.jpg
#   inflating: 4scenes/forest_text35.jpg
#   inflating: 4scenes/forest_text21.jpg
#   inflating: 4scenes/coast_nat743.jpg
#   inflating: 4scenes/highway_a866042.jpg
#   inflating: 4scenes/street_par107.jpg
#   inflating: 4scenes/coast_natu777.jpg
#   inflating: 4scenes/forest_nat219.jpg
#   inflating: 4scenes/forest_land222.jpg
#   inflating: 4scenes/coast_natu776.jpg
#   inflating: 4scenes/forest_natu161.jpg
#   inflating: 4scenes/coast_natu986.jpg
#   inflating: 4scenes/forest_text20.jpg
#   inflating: 4scenes/street_par112.jpg
#   inflating: 4scenes/highway_urb545.jpg
#   inflating: 4scenes/highway_bost296.jpg
#   inflating: 4scenes/street_urb104.jpg
#   inflating: 4scenes/forest_for25.jpg
#   inflating: 4scenes/coast_n291075.jpg
#   inflating: 4scenes/coast_n291061.jpg
#   inflating: 4scenes/coast_natu789.jpg
#   inflating: 4scenes/forest_natu439.jpg
#   inflating: 4scenes/coast_n286045.jpg
#   inflating: 4scenes/coast_bea29.jpg
#   inflating: 4scenes/coast_n295011.jpg
#   inflating: 4scenes/highway_urb784.jpg
#   inflating: 4scenes/forest_nat146.jpg
#   inflating: 4scenes/coast_art487.jpg
#   inflating: 4scenes/forest_cdmc348.jpg
#   inflating: 4scenes/highway_gre472.jpg
#   inflating: 4scenes/coast_natu399.jpg
#   inflating: 4scenes/highway_gre466.jpg
#   inflating: 4scenes/street_street22.jpg
#   inflating: 4scenes/street_gre219.jpg
#   inflating: 4scenes/highway_bost335.jpg
#   inflating: 4scenes/highway_bost321.jpg
#   inflating: 4scenes/highway_art803.jpg
#   inflating: 4scenes/highway_bost309.jpg
#   inflating: 4scenes/coast_cdmc991.jpg
#   inflating: 4scenes/highway_gre658.jpg
#   inflating: 4scenes/street_a714064.jpg
#   inflating: 4scenes/coast_natu819.jpg
#   inflating: 4scenes/street_art1688.jpg
#   inflating: 4scenes/coast_natu825.jpg
#   inflating: 4scenes/coast_natu827.jpg
#   inflating: 4scenes/coast_nat807.jpg
#   inflating: 4scenes/street_urb927.jpg
#   inflating: 4scenes/highway_bost323.jpg
#   inflating: 4scenes/highway_gre470.jpg
#   inflating: 4scenes/highway_gre458.jpg
#   inflating: 4scenes/coast_n739046.jpg
#   inflating: 4scenes/coast_n203071.jpg
#   inflating: 4scenes/highway_nat520.jpg
#   inflating: 4scenes/street_urb304.jpg
#   inflating: 4scenes/highway_gre504.jpg
#   inflating: 4scenes/coast_sun15.jpg
#   inflating: 4scenes/street_gre186.jpg
#   inflating: 4scenes/highway_gre538.jpg
#   inflating: 4scenes/coast_n203059.jpg
#   inflating: 4scenes/highway_urb962.jpg
#   inflating: 4scenes/coast_osun52.jpg
#   inflating: 4scenes/street_gre179.jpg
#   inflating: 4scenes/forest_natu361.jpg
#   inflating: 4scenes/forest_for27.jpg
#   inflating: 4scenes/forest_for136.jpg
#   inflating: 4scenes/highway_n480045.jpg
#   inflating: 4scenes/highway_bost294.jpg
#   inflating: 4scenes/highway_a866041.jpg
#   inflating: 4scenes/forest_natu611.jpg
#   inflating: 4scenes/forest_natu163.jpg
#   inflating: 4scenes/coast_cdmc830.jpg
#   inflating: 4scenes/coast_nat768.jpg
#   inflating: 4scenes/street_par29.jpg
#   inflating: 4scenes/street_art475.jpg
#   inflating: 4scenes/coast_nat1149.jpg
#   inflating: 4scenes/street_par28.jpg
#   inflating: 4scenes/coast_cdmc825.jpg
#   inflating: 4scenes/coast_nat1175.jpg
#   inflating: 4scenes/street_par14.jpg
#   inflating: 4scenes/coast_nat755.jpg
#   inflating: 4scenes/coast_land386.jpg
#   inflating: 4scenes/highway_bost295.jpg
#   inflating: 4scenes/forest_for137.jpg
#   inflating: 4scenes/street_urb885.jpg
#   inflating: 4scenes/forest_for32.jpg
#   inflating: 4scenes/street_urb661.jpg
#   inflating: 4scenes/coast_n291076.jpg
#   inflating: 4scenes/highway_urb744.jpg
#   inflating: 4scenes/coast_sun28.jpg
#   inflating: 4scenes/highway_art237.jpg
#   inflating: 4scenes/coast_sun14.jpg
#   inflating: 4scenes/highway_art579.jpg
#   inflating: 4scenes/highway_gre277.jpg
#   inflating: 4scenes/street_urb305.jpg
#   inflating: 4scenes/street_gre193.jpg
#   inflating: 4scenes/coast_land812.jpg
#   inflating: 4scenes/forest_cdmc388.jpg
#   inflating: 4scenes/coast_n424079.jpg
#   inflating: 4scenes/forest_nat145.jpg
#   inflating: 4scenes/forest_nat623.jpg
#   inflating: 4scenes/coast_n739047.jpg
#   inflating: 4scenes/highway_gre459.jpg
#   inflating: 4scenes/forest_cdmc377.jpg
#   inflating: 4scenes/street_urb265.jpg
#   inflating: 4scenes/forest_cdmc363.jpg
#   inflating: 4scenes/highway_bost322.jpg
#   inflating: 4scenes/highway_bost336.jpg
#   inflating: 4scenes/coast_cdmc951.jpg
#   inflating: 4scenes/forest_nat347.jpg
#   inflating: 4scenes/forest_natu994.jpg
#   inflating: 4scenes/coast_natu826.jpg
#   inflating: 4scenes/street_a79094.jpg
#   inflating: 4scenes/coast_nat194.jpg
#   inflating: 4scenes/coast_bea9.jpg
#   inflating: 4scenes/coast_natu822.jpg
#   inflating: 4scenes/coast_cdmc955.jpg
#   inflating: 4scenes/highway_bost332.jpg
#   inflating: 4scenes/highway_bost326.jpg
#   inflating: 4scenes/coast_cdmc969.jpg
#   inflating: 4scenes/highway_gre475.jpg
#   inflating: 4scenes/forest_land807.jpg
#   inflating: 4scenes/forest_cdmc415.jpg
#   inflating: 4scenes/highway_gre36.jpg
#   inflating: 4scenes/highway_land409.jpg
#   inflating: 4scenes/street_art1328.jpg
#   inflating: 4scenes/street_boston46.jpg
#   inflating: 4scenes/street_art869.jpg
#   inflating: 4scenes/highway_art596.jpg
#   inflating: 4scenes/forest_cdmc12.jpg
#   inflating: 4scenes/forest_natu402.jpg
#   inflating: 4scenes/highway_urb754.jpg
#   inflating: 4scenes/highway_bost291.jpg
#   inflating: 4scenes/forest_for127.jpg
#   inflating: 4scenes/forest_for22.jpg
#   inflating: 4scenes/coast_cdmc821.jpg
#   inflating: 4scenes/forest_natu172.jpg
#   inflating: 4scenes/forest_land224.jpg
#   inflating: 4scenes/coast_land341.jpg
#   inflating: 4scenes/coast_land369.jpg
#   inflating: 4scenes/coast_natu981.jpg
#   inflating: 4scenes/coast_nat745.jpg
#   inflating: 4scenes/forest_nat223.jpg
#   inflating: 4scenes/street_par101.jpg
#   inflating: 4scenes/coast_land368.jpg
#   inflating: 4scenes/forest_text26.jpg
#   inflating: 4scenes/street_par100.jpg
#   inflating: 4scenes/forest_land219.jpg
#   inflating: 4scenes/coast_land340.jpg
#   inflating: 4scenes/highway_bost290.jpg
#   inflating: 4scenes/forest_for132.jpg
#   inflating: 4scenes/coast_osun56.jpg
#   inflating: 4scenes/forest_nat1217.jpg
#   inflating: 4scenes/forest_land741.jpg
#   inflating: 4scenes/coast_sun11.jpg
#   inflating: 4scenes/forest_tell51.jpg
#   inflating: 4scenes/highway_art568.jpg
#   inflating: 4scenes/coast_sun39.jpg
#   inflating: 4scenes/highway_nat518.jpg
#   inflating: 4scenes/highway_gre37.jpg
#   inflating: 4scenes/street_urb506.jpg
#   inflating: 4scenes/forest_cdmc414.jpg
#   inflating: 4scenes/highway_gre474.jpg
#   inflating: 4scenes/street_urb274.jpg
#   inflating: 4scenes/coast_natu638.jpg
#   inflating: 4scenes/street_a281067.jpg
#   inflating: 4scenes/coast_natu604.jpg
#   inflating: 4scenes/coast_cdmc940.jpg
#   inflating: 4scenes/coast_cdmc954.jpg
#   inflating: 4scenes/street_art511.jpg
#   inflating: 4scenes/coast_n344048.jpg
#   inflating: 4scenes/highway_gre662.jpg
#   inflating: 4scenes/coast_cdmc997.jpg
#   inflating: 4scenes/forest_natc13.jpg
#   inflating: 4scenes/highway_art608.jpg
#   inflating: 4scenes/coast_n243057.jpg
#   inflating: 4scenes/coast_n672069.jpg
#   inflating: 4scenes/coast_cdmc942.jpg
#   inflating: 4scenes/highway_bost325.jpg
#   inflating: 4scenes/street_gre209.jpg
#   inflating: 4scenes/highway_bost331.jpg
#   inflating: 4scenes/highway_art813.jpg
#   inflating: 4scenes/highway_bost319.jpg
#   inflating: 4scenes/forest_nat354.jpg
#   inflating: 4scenes/street_a805038.jpg
#   inflating: 4scenes/forest_cdmc358.jpg
#   inflating: 4scenes/highway_gre462.jpg
#   inflating: 4scenes/forest_land810.jpg
#   inflating: 4scenes/coast_arnat59.jpg
#   inflating: 4scenes/street_urb510.jpg
#   inflating: 4scenes/highway_gre476.jpg
#   inflating: 4scenes/coast_n424081.jpg
#   inflating: 4scenes/street_boston79.jpg
#   inflating: 4scenes/highway_gre35.jpg
#   inflating: 4scenes/coast_bea39.jpg
#   inflating: 4scenes/forest_cdmc562.jpg
#   inflating: 4scenes/highway_nat526.jpg
#   inflating: 4scenes/coast_n286096.jpg
#   inflating: 4scenes/highway_urb743.jpg
#   inflating: 4scenes/coast_osun54.jpg
#   inflating: 4scenes/highway_bost292.jpg
#   inflating: 4scenes/forest_for130.jpg
#   inflating: 4scenes/coast_natu772.jpg
#   inflating: 4scenes/forest_nat208.jpg
#   inflating: 4scenes/street_par116.jpg
#   inflating: 4scenes/highway_a866047.jpg
#   inflating: 4scenes/forest_nat220.jpg
#   inflating: 4scenes/street_par102.jpg
#   inflating: 4scenes/street_par103.jpg
#   inflating: 4scenes/forest_nat221.jpg
#   inflating: 4scenes/forest_natu158.jpg
#   inflating: 4scenes/street_par12.jpg
#   inflating: 4scenes/forest_natu170.jpg
#   inflating: 4scenes/forest_natu164.jpg
#   inflating: 4scenes/forest_nat209.jpg
#   inflating: 4scenes/forest_for20.jpg
#   inflating: 4scenes/coast_natu798.jpg
#   inflating: 4scenes/forest_for119.jpg
#   inflating: 4scenes/highway_bost293.jpg
#   inflating: 4scenes/street_art880.jpg
#   inflating: 4scenes/forest_natu428.jpg
#   inflating: 4scenes/highway_art580.jpg
#   inflating: 4scenes/street_gre181.jpg
#   inflating: 4scenes/coast_sun12.jpg
#   inflating: 4scenes/coast_bea38.jpg
#   inflating: 4scenes/highway_nat533.jpg
#   inflating: 4scenes/coast_bea10.jpg
#   inflating: 4scenes/street_boston286.jpg
#   inflating: 4scenes/forest_nat619.jpg
#   inflating: 4scenes/coast_n384092.jpg
#   inflating: 4scenes/street_art923.jpg
#   inflating: 4scenes/forest_cdmc359.jpg
#   inflating: 4scenes/highway_bost318.jpg
#   inflating: 4scenes/street_street27.jpg
#   inflating: 4scenes/highway_bost330.jpg
#   inflating: 4scenes/coast_land237.jpg
#   inflating: 4scenes/highway_bost324.jpg
#   inflating: 4scenes/street_enc48.jpg
#   inflating: 4scenes/coast_nat196.jpg
#   inflating: 4scenes/coast_natu820.jpg
#   inflating: 4scenes/highway_gre661.jpg
#   inflating: 4scenes/coast_natu808.jpg
#   inflating: 4scenes/forest_natc12.jpg
#   inflating: 4scenes/street_gre2.jpg
#   inflating: 4scenes/forest_text106.jpg
#   inflating: 4scenes/forest_natc49.jpg
#   inflating: 4scenes/highway_bost394.jpg
#   inflating: 4scenes/street_par9.jpg
#   inflating: 4scenes/street_art549.jpg
#   inflating: 4scenes/coast_natu648.jpg
#   inflating: 4scenes/coast_nat1074.jpg
#   inflating: 4scenes/coast_cdmc924.jpg
#   inflating: 4scenes/forest_land335.jpg
#   inflating: 4scenes/forest_nat468.jpg
#   inflating: 4scenes/highway_gre404.jpg
#   inflating: 4scenes/street_urb562.jpg
#   inflating: 4scenes/forest_land862.jpg
#   inflating: 4scenes/coast_n347041.jpg
#   inflating: 4scenes/highway_gre410.jpg
#   inflating: 4scenes/highway_art336.jpg
#   inflating: 4scenes/highway_bost182.jpg
#   inflating: 4scenes/forest_cdmc458.jpg
#   inflating: 4scenes/highway_bost169.jpg
#   inflating: 4scenes/forest_nat130.jpg
#   inflating: 4scenes/highway_gre53.jpg
#   inflating: 4scenes/coast_sun5.jpg
#   inflating: 4scenes/street_urb589.jpg
#   inflating: 4scenes/highway_bost155.jpg
#   inflating: 4scenes/coast_nat293.jpg
#   inflating: 4scenes/coast_n203011.jpg
#   inflating: 4scenes/street_boston356.jpg
#   inflating: 4scenes/street_bost65.jpg
#   inflating: 4scenes/street_gre131.jpg
#   inflating: 4scenes/forest_natu18.jpg
#   inflating: 4scenes/forest_for47.jpg
#   inflating: 4scenes/coast_n241020.jpg
#   inflating: 4scenes/forest_text81.jpg
#   inflating: 4scenes/forest_for142.jpg
#   inflating: 4scenes/coast_nat907.jpg
#   inflating: 4scenes/forest_natu895.jpg
#   inflating: 4scenes/forest_for84.jpg
#   inflating: 4scenes/coast_cdmc878.jpg
#   inflating: 4scenes/forest_text42.jpg
#   inflating: 4scenes/coast_cdmc850.jpg
#   inflating: 4scenes/street_par49.jpg
#   inflating: 4scenes/street_par158.jpg
#   inflating: 4scenes/coast_cdmc845.jpg
#   inflating: 4scenes/coast_cdmc851.jpg
#   inflating: 4scenes/forest_for85.jpg
#   inflating: 4scenes/street_par165.jpg
#   inflating: 4scenes/forest_text43.jpg
#   inflating: 4scenes/street_par74.jpg
#   inflating: 4scenes/forest_for157.jpg
#   inflating: 4scenes/forest_natu31.jpg
#   inflating: 4scenes/coast_n736062.jpg
#   inflating: 4scenes/forest_for143.jpg
#   inflating: 4scenes/coast_land480.jpg
#   inflating: 4scenes/coast_n228083.jpg
#   inflating: 4scenes/forest_for52.jpg
#   inflating: 4scenes/coast_n238045.jpg
#   inflating: 4scenes/street_gre130.jpg
#   inflating: 4scenes/street_gre124.jpg
#   inflating: 4scenes/forest_nat1266.jpg
#   inflating: 4scenes/street_bost64.jpg
#   inflating: 4scenes/forest_cdmc277.jpg
#   inflating: 4scenes/forest_for3.jpg
#   inflating: 4scenes/coast_nat292.jpg
#   inflating: 4scenes/coast_n203004.jpg
#   inflating: 4scenes/highway_gre52.jpg
#   inflating: 4scenes/highway_bost154.jpg
#   inflating: 4scenes/coast_sun4.jpg
#   inflating: 4scenes/street_art762.jpg
#   inflating: 4scenes/highway_gre46.jpg
#   inflating: 4scenes/highway_bost168.jpg
#   inflating: 4scenes/highway_bost183.jpg
#   inflating: 4scenes/street_hexp21.jpg
#   inflating: 4scenes/highway_gre411.jpg
#   inflating: 4scenes/forest_cdmc317.jpg
#   inflating: 4scenes/forest_land863.jpg
#   inflating: 4scenes/coast_natu649.jpg
#   inflating: 4scenes/highway_art874.jpg
#   inflating: 4scenes/coast_nat899.jpg
#   inflating: 4scenes/highway_bost395.jpg
#   inflating: 4scenes/highway_gre149.jpg
#   inflating: 4scenes/coast_nat866.jpg
#   inflating: 4scenes/forest_text107.jpg
#   inflating: 4scenes/forest_cdmc101.jpg
#   inflating: 4scenes/street_art1199.jpg
#   inflating: 4scenes/coast_n243030.jpg
#   inflating: 4scenes/street_urb761.jpg
#   inflating: 4scenes/forest_text105.jpg
#   inflating: 4scenes/forest_text111.jpg
#   inflating: 4scenes/highway_bost397.jpg
#   inflating: 4scenes/street_street94.jpg
#   inflating: 4scenes/coast_nat643.jpg
#   inflating: 4scenes/forest_nat325.jpg
#   inflating: 4scenes/coast_natu887.jpg
#   inflating: 4scenes/coast_cdmc933.jpg
#   inflating: 4scenes/coast_cdmc927.jpg
#   inflating: 4scenes/coast_land253.jpg
#   inflating: 4scenes/coast_nat496.jpg
#   inflating: 4scenes/highway_gre413.jpg
#   inflating: 4scenes/forest_land861.jpg
#   inflating: 4scenes/forest_cdmc315.jpg
#   inflating: 4scenes/highway_gre407.jpg
#   inflating: 4scenes/coast_nat482.jpg
#   inflating: 4scenes/street_boston235.jpg
#   inflating: 4scenes/forest_land849.jpg
#   inflating: 4scenes/street_hexp23.jpg
#   inflating: 4scenes/highway_bost181.jpg
#   inflating: 4scenes/highway_bost156.jpg
#   inflating: 4scenes/highway_gre50.jpg
#   inflating: 4scenes/street_art760.jpg
#   inflating: 4scenes/highway_nat543.jpg
#   inflating: 4scenes/coast_nat284.jpg
#   inflating: 4scenes/forest_cdmc507.jpg
#   inflating: 4scenes/highway_art255.jpg
#   inflating: 4scenes/coast_natu25.jpg
#   inflating: 4scenes/street_bost72.jpg
#   inflating: 4scenes/street_a205062.jpg
#   inflating: 4scenes/street_gre126.jpg
#   inflating: 4scenes/street_art1206.jpg
#   inflating: 4scenes/forest_land726.jpg
#   inflating: 4scenes/coast_natu515.jpg
#   inflating: 4scenes/street_boston396.jpg
#   inflating: 4scenes/coast_n486055.jpg
#   inflating: 4scenes/highway_art1696.jpg
#   inflating: 4scenes/forest_for44.jpg
#   inflating: 4scenes/forest_nat286.jpg
#   inflating: 4scenes/forest_for50.jpg
#   inflating: 4scenes/highway_art1682.jpg
#   inflating: 4scenes/forest_natu869.jpg
#   inflating: 4scenes/street_par198.jpg
#   inflating: 4scenes/coast_nat904.jpg
#   inflating: 4scenes/forest_for78.jpg
#   inflating: 4scenes/coast_nat910.jpg
#   inflating: 4scenes/forest_text41.jpg
#   inflating: 4scenes/forest_for87.jpg
#   inflating: 4scenes/forest_for93.jpg
#   inflating: 4scenes/street_par76.jpg
#   inflating: 4scenes/street_urb830.jpg
#   inflating: 4scenes/coast_cdmc853.jpg
#   inflating: 4scenes/coast_natu702.jpg
#   inflating: 4scenes/forest_land243.jpg
#   inflating: 4scenes/street_par77.jpg
#   inflating: 4scenes/coast_nat736.jpg
#   inflating: 4scenes/forest_text40.jpg
#   inflating: 4scenes/forest_for86.jpg
#   inflating: 4scenes/street_par88.jpg
#   inflating: 4scenes/forest_natu26.jpg
#   inflating: 4scenes/coast_cdmc891.jpg
#   inflating: 4scenes/coast_natu919.jpg
#   inflating: 4scenes/forest_for79.jpg
#   inflating: 4scenes/coast_nat905.jpg
#   inflating: 4scenes/street_par199.jpg
#   inflating: 4scenes/forest_urb753.jpg
#   inflating: 4scenes/forest_land733.jpg
#   inflating: 4scenes/street_boston397.jpg
#   inflating: 4scenes/street_urb19.jpg
#   inflating: 4scenes/forest_land727.jpg
#   inflating: 4scenes/forest_natu317.jpg
#   inflating: 4scenes/highway_art254.jpg
#   inflating: 4scenes/coast_nat285.jpg
#   inflating: 4scenes/highway_nat542.jpg
#   inflating: 4scenes/highway_gre45.jpg
#   inflating: 4scenes/street_art761.jpg
#   inflating: 4scenes/highway_bost157.jpg
#   inflating: 4scenes/street_art775.jpg
#   inflating: 4scenes/coast_sun7.jpg
#   inflating: 4scenes/street_boston21.jpg
#   inflating: 4scenes/forest_nat867.jpg
#   inflating: 4scenes/street_hexp22.jpg
#   inflating: 4scenes/highway_bost180.jpg
#   inflating: 4scenes/street_a232022.jpg
#   inflating: 4scenes/street_urb206.jpg
#   inflating: 4scenes/highway_gre406.jpg
#   inflating: 4scenes/forest_nat697.jpg
#   inflating: 4scenes/street_street56.jpg
#   inflating: 4scenes/street_land767.jpg
#   inflating: 4scenes/street_city91.jpg
#   inflating: 4scenes/forest_natu707.jpg
#   inflating: 4scenes/forest_nat324.jpg
#   inflating: 4scenes/coast_n708004.jpg
#   inflating: 4scenes/coast_nat642.jpg
#   inflating: 4scenes/street_gre251.jpg
#   inflating: 4scenes/forest_nat442.jpg
#   inflating: 4scenes/coast_nat865.jpg
#   inflating: 4scenes/coast_n672031.jpg
#   inflating: 4scenes/forest_natu934.jpg
#   inflating: 4scenes/highway_gre610.jpg
#   inflating: 4scenes/street_street85.jpg
#   inflating: 4scenes/highway_bost392.jpg
#   inflating: 4scenes/street_city42.jpg
#   inflating: 4scenes/street_enc15.jpg
#   inflating: 4scenes/coast_nat1099.jpg
#   inflating: 4scenes/coast_n672021.jpg
#   inflating: 4scenes/coast_cdmc922.jpg
#   inflating: 4scenes/coast_natu666.jpg
#   inflating: 4scenes/coast_natu128.jpg
#   inflating: 4scenes/forest_nat452.jpg
#   inflating: 4scenes/coast_nat120.jpg
#   inflating: 4scenes/forest_cdmc338.jpg
#   inflating: 4scenes/highway_bost184.jpg
#   inflating: 4scenes/coast_n384030.jpg
#   inflating: 4scenes/forest_land858.jpg
#   inflating: 4scenes/forest_land870.jpg
#   inflating: 4scenes/highway_gre402.jpg
#   inflating: 4scenes/forest_land864.jpg
#   inflating: 4scenes/coast_n347047.jpg
#   inflating: 4scenes/highway_gre55.jpg
#   inflating: 4scenes/coast_sun3.jpg
#   inflating: 4scenes/street_art771.jpg
#   inflating: 4scenes/highway_bost153.jpg
#   inflating: 4scenes/street_boston19.jpg
#   inflating: 4scenes/highway_bost147.jpg
#   inflating: 4scenes/coast_art1130.jpg
#   inflating: 4scenes/highway_gre41.jpg
#   inflating: 4scenes/street_art759.jpg
#   inflating: 4scenes/highway_art250.jpg
#   inflating: 4scenes/street_bost77.jpg
#   inflating: 4scenes/highway_nat546.jpg
#   inflating: 4scenes/street_boston378.jpg
#   inflating: 4scenes/forest_land81.jpg
#   inflating: 4scenes/coast_land108.jpg
#   inflating: 4scenes/street_bost104.jpg
#   inflating: 4scenes/forest_nat1088.jpg
#   inflating: 4scenes/coast_nat901.jpg
#   inflating: 4scenes/highway_n480023.jpg
#   inflating: 4scenes/forest_natu850.jpg
#   inflating: 4scenes/highway_art1693.jpg
#   inflating: 4scenes/street_par162.jpg
#   inflating: 4scenes/forest_for82.jpg
#   inflating: 4scenes/forest_text44.jpg
#   inflating: 4scenes/forest_text50.jpg
#   inflating: 4scenes/coast_n228047.jpg
#   inflating: 4scenes/coast_nat1112.jpg
#   inflating: 4scenes/forest_for96.jpg
#   inflating: 4scenes/street_par177.jpg
#   inflating: 4scenes/street_par72.jpg
#   inflating: 4scenes/coast_n328052.jpg
#   inflating: 4scenes/forest_text45.jpg
#   inflating: 4scenes/highway_art1679.jpg
#   inflating: 4scenes/street_urb834.jpg
#   inflating: 4scenes/street_artc27.jpg
#   inflating: 4scenes/coast_natu920.jpg
#   inflating: 4scenes/coast_natu908.jpg
#   inflating: 4scenes/highway_n480036.jpg
#   inflating: 4scenes/street_par188.jpg
#   inflating: 4scenes/forest_for151.jpg
#   inflating: 4scenes/coast_nat900.jpg
#   inflating: 4scenes/street_par99.jpg
#   inflating: 4scenes/street_gre122.jpg
#   inflating: 4scenes/street_bost89.jpg
#   inflating: 4scenes/street_bost105.jpg
#   inflating: 4scenes/street_bost111.jpg
#   inflating: 4scenes/forest_nat719.jpg
#   inflating: 4scenes/forest_nat1248.jpg
#   inflating: 4scenes/coast_nat294.jpg
#   inflating: 4scenes/forest_cdmc271.jpg
#   inflating: 4scenes/street_boston379.jpg
#   inflating: 4scenes/street_boston351.jpg
#   inflating: 4scenes/street_bost76.jpg
#   inflating: 4scenes/highway_gre239.jpg
#   inflating: 4scenes/street_boston345.jpg
#   inflating: 4scenes/street_art758.jpg
#   inflating: 4scenes/coast_nat1265.jpg
#   inflating: 4scenes/coast_n424023.jpg
#   inflating: 4scenes/street_art764.jpg
#   inflating: 4scenes/coast_nat479.jpg
#   inflating: 4scenes/street_boston18.jpg
#   inflating: 4scenes/highway_gre40.jpg
#   inflating: 4scenes/highway_bost152.jpg
#   inflating: 4scenes/highway_gre403.jpg
#   inflating: 4scenes/forest_land871.jpg
#   inflating: 4scenes/highway_urb681.jpg
#   inflating: 4scenes/highway_bost185.jpg
#   inflating: 4scenes/coast_natu667.jpg
#   inflating: 4scenes/coast_cdmc923.jpg
#   inflating: 4scenes/street_urb798.jpg
#   inflating: 4scenes/street_street47.jpg
#   inflating: 4scenes/coast_nat109.jpg
#   inflating: 4scenes/coast_nat684.jpg
#   inflating: 4scenes/street_urb983.jpg
#   inflating: 4scenes/highway_bost387.jpg
#   inflating: 4scenes/highway_bost393.jpg
#   inflating: 4scenes/coast_n672034.jpg
#   inflating: 4scenes/coast_land296.jpg
#   inflating: 4scenes/forest_bost190.jpg
#   inflating: 4scenes/street_gre295.jpg
#   inflating: 4scenes/coast_cdmc706.jpg
#   inflating: 4scenes/forest_text103.jpg
#   inflating: 4scenes/forest_nat1128.jpg
#   inflating: 4scenes/street_art1162.jpg
#   inflating: 4scenes/coast_nat1065.jpg
#   inflating: 4scenes/forest_nat451.jpg
#   inflating: 4scenes/forest_nat337.jpg
#   inflating: 4scenes/highway_bost187.jpg
#   inflating: 4scenes/forest_land867.jpg
#   inflating: 4scenes/forest_cdmc313.jpg
#   inflating: 4scenes/street_art799.jpg
#   inflating: 4scenes/highway_gre415.jpg
#   inflating: 4scenes/coast_land902.jpg
#   inflating: 4scenes/forest_land873.jpg
#   inflating: 4scenes/highway_gre42.jpg
#   inflating: 4scenes/street_art766.jpg
#   inflating: 4scenes/highway_bost150.jpg
#   inflating: 4scenes/coast_natu473.jpg
#   inflating: 4scenes/street_par203.jpg
#   inflating: 4scenes/highway_bost178.jpg
#   inflating: 4scenes/street_boston32.jpg
#   inflating: 4scenes/street_boston353.jpg
#   inflating: 4scenes/street_bost60.jpg
#   inflating: 4scenes/highway_urb720.jpg
#   inflating: 4scenes/highway_n480020.jpg
#   inflating: 4scenes/forest_for153.jpg
#   inflating: 4scenes/forest_natu847.jpg
#   inflating: 4scenes/forest_text90.jpg
#   inflating: 4scenes/forest_for42.jpg
#   inflating: 4scenes/forest_natc4.jpg
#   inflating: 4scenes/coast_cdmc841.jpg
#   inflating: 4scenes/forest_for95.jpg
#   inflating: 4scenes/street_par70.jpg
#   inflating: 4scenes/coast_land309.jpg
#   inflating: 4scenes/forest_text47.jpg
#   inflating: 4scenes/street_par161.jpg
#   inflating: 4scenes/street_par64.jpg
#   inflating: 4scenes/highway_par23.jpg
#   inflating: 4scenes/forest_text46.jpg
#   inflating: 4scenes/highway_urb537.jpg
#   inflating: 4scenes/highway_art1134.jpg
#   inflating: 4scenes/street_par160.jpg
#   inflating: 4scenes/coast_natu704.jpg
#   inflating: 4scenes/coast_land334.jpg
#   inflating: 4scenes/forest_land245.jpg
#   inflating: 4scenes/street_par59.jpg
#   inflating: 4scenes/street_urb837.jpg
#   inflating: 4scenes/coast_natu923.jpg
#   inflating: 4scenes/coast_n228092.jpg
#   inflating: 4scenes/forest_nat281.jpg
#   inflating: 4scenes/forest_natu846.jpg
#   inflating: 4scenes/coast_n241018.jpg
#   inflating: 4scenes/forest_for146.jpg
#   inflating: 4scenes/street_gre135.jpg
#   inflating: 4scenes/street_gre653.jpg
#   inflating: 4scenes/street_gre121.jpg
#   inflating: 4scenes/coast_nat283.jpg
#   inflating: 4scenes/coast_n203015.jpg
#   inflating: 4scenes/highway_nat550.jpg
#   inflating: 4scenes/street_boston408.jpg
#   inflating: 4scenes/highway_art252.jpg
#   inflating: 4scenes/coast_sun59.jpg
#   inflating: 4scenes/street_bost75.jpg
#   inflating: 4scenes/highway_bost179.jpg
#   inflating: 4scenes/highway_bost151.jpg
#   inflating: 4scenes/coast_sun1.jpg
#   inflating: 4scenes/street_gre11.jpg
#   inflating: 4scenes/street_art767.jpg
#   inflating: 4scenes/coast_nat491.jpg
#   inflating: 4scenes/highway_gre414.jpg
#   inflating: 4scenes/forest_cdmc306.jpg
#   inflating: 4scenes/forest_land872.jpg
#   inflating: 4scenes/street_urb200.jpg
#   inflating: 4scenes/forest_land866.jpg
#   inflating: 4scenes/street_art798.jpg
#   inflating: 4scenes/highway_gre400.jpg
#   inflating: 4scenes/street_urb228.jpg
#   inflating: 4scenes/coast_n384026.jpg
#   inflating: 4scenes/street_hexp30.jpg
#   inflating: 4scenes/highway_bost186.jpg
#   inflating: 4scenes/forest_nat450.jpg
#   inflating: 4scenes/coast_cdmc934.jpg
#   inflating: 4scenes/coast_natu670.jpg
#   inflating: 4scenes/street_street50.jpg
#   inflating: 4scenes/forest_text102.jpg

# %%
# construindo a base de dados a partir das features extraídas do conjunto 4scenes

imagesPath = './4scenes'
labels = []
data = []

files = os.listdir(imagesPath)

print("[INFO] extraindo features...")

# loop em todas as imagens do diretório
for image_name in files:
  # extraindo o rótulo das imagens (primeira parte do nome do arquivo)
  label = image_name[image_name.rfind("/") + 1:].split("_")[0]
  # carregando a imagem
  image = cv2.imread(imagesPath+'/'+image_name)  
  # extraindo as features da imagem
  features = describe(image)
  # adicionando o rótulo da imagem (classe) em uma lista de rótulos
  labels.append(label)
  # adicionando a imagem (features) ao conjunto de dados
  data.append(features)
# Out:
# [INFO] extraindo features...

# %% [markdown]
# Vamos analisar os metadados. Ou seja, como era o conjunto de dados original e como está disposto a base de dados criada a partir da extração de caraterísticas das imagens.

# %%
sample_image = cv2.imread('4scenes/coast_arnat59.jpg')
print(f'Tamanho da imagem: {sample_image.shape}')
cv2_imshow(sample_image)
# Out:
# Tamanho da imagem: (256, 256, 3)
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F887055C490>

# %%
sample_data = data[0]
print(f'Tamanho da entrada na BD: {sample_data.shape}')
print(sample_data)
# Out:
# Tamanho da entrada na BD: (19,)
# [ 7.89977112e+01  4.14616089e+01  1.44286057e+02  2.46149428e+01
#   3.25208259e+01  4.51333302e+01  1.04417230e-03  1.44309287e+02
#   9.49845550e-01  1.43838099e+03  3.44761889e-01  2.65066011e+02
#   5.60921467e+03  8.09088591e+00  1.14031710e+01  4.82030230e-04
#   3.81635134e+00 -3.99661206e-01  9.97846441e-01]

# %% [markdown]
# ## Dividir a base de dados
#
# Como de praxe, vamos dividir a base de dados com um *holdout* de 75/25 para treinamento e teste.

# %%
# construir as bases de treinamento e teste
(trainData, testData, trainLabels, testLabels) = train_test_split(np.array(data),
	np.array(labels), test_size=0.25, random_state=42)

# %% [markdown]
# ## Treinar modelo
#
# Vamos construir um modelo baseado em árvore de decisão para classificar as imagens. Não vamos otimizar o classificador e a configuração utilizada é a padrão.

# %%
# iniciar o modelo como árvore de decisão
model = DecisionTreeClassifier(random_state=84)
# treinar o modelo
print("[INFO] treinando modelo...")
model.fit(trainData, trainLabels)
# Out:
# [INFO] treinando modelo...
# DecisionTreeClassifier(random_state=84)

# %% [markdown]
# ## Avaliar modelo
#
# Por fim, vamos avaliar como foi o treinamento do simples modelo criado para classificar as imagens de cenários em um conjunto de imagens nunca vista por esse modelo (conjunto de teste). Para isso, os resultados de precisão, revocação e *f-measure* vão ser exibidos.

# %%
print("[INFO] avaliando...")
predictions = model.predict(testData)
print(classification_report(testLabels, predictions))
# Out:
# [INFO] avaliando...
#               precision    recall  f1-score   support
#
#        coast       0.73      0.74      0.73        87
#       forest       0.92      0.78      0.85        77
#      highway       0.67      0.79      0.73        57
#       street       0.78      0.79      0.78        89
#
#     accuracy                           0.77       310
#    macro avg       0.77      0.77      0.77       310
# weighted avg       0.78      0.77      0.77       310

# %% [markdown]
# ## Testando manualmente o modelo
#
# Para entender melhor o que esses resultados significam na prática, vamos visualizar algumas das predições feitas por ele.

# %%
imagesPath = './4scenes'
labels = []
data = []

files = os.listdir(imagesPath)

print("[INFO] extraindo features...")

# loop em todas as imagens do diretório
for image_name in files:
  # extraindo o rótulo das imagens (primeira parte do nome do arquivo)
  label = image_name[image_name.rfind("/") + 1:].split("_")[0]
  # carregando a imagem
  image = cv2.imread(imagesPath+'/'+image_name)  
  # extraindo as features da imagem
  features = describe(image)
  # adicionando o rótulo da imagem (classe) em uma lista de rótulos
  labels.append(label)
  # adicionando a imagem (features) ao conjunto de dados
  data.append(features)
# Out:
# [INFO] extraindo features...

# %%
# loop em algumas imagens aleatórias
for i in np.random.randint(0, high=len(files), size=(10,)):
	# pega a imagem e classifica
	imagePath = imagesPath + '/' + files[i]
	filename = files[i]
	image = cv2.imread(imagePath)
	features = describe(image)
	prediction = model.predict(features.reshape(1, -1))[0]
	# mostra a predição
	print("[PREDIÇÃO] {}: {}".format(filename, prediction))
	cv2.putText(image, prediction, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 255, 0), 2)
	cv2_imshow(image)
# Out:
# [PREDIÇÃO] coast_sun15.jpg: coast
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F887066E750>
# [PREDIÇÃO] forest_land222.jpg: forest
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F886A3A38D0>
# [PREDIÇÃO] forest_nat221.jpg: forest
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F887066EE90>
# [PREDIÇÃO] forest_nat623.jpg: forest
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8870680350>
# [PREDIÇÃO] coast_n241020.jpg: coast
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F887066E7D0>
# [PREDIÇÃO] highway_urb720.jpg: highway
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F886A3A38D0>
# [PREDIÇÃO] forest_nat470.jpg: forest
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F886A3A38D0>
# [PREDIÇÃO] highway_bost159.jpg: highway
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F886A36C710>
# [PREDIÇÃO] highway_gre48.jpg: highway
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F886A3A38D0>
# [PREDIÇÃO] highway_bost155.jpg: highway
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F886A3A38D0>

# %% [markdown]
# # Random Forests
#
# Existem versões mais recentes que trabalham com comitês de árvores de decisão. Isso significa que são construídas várias árvores e a decisão final não é dada somente por um classificador, mas pela combinação dos resultados de vários deles. Nesse caso, várias árvores de decisão. Esse modelo é conhecido como *Random Forests*. Para mais detalhes, consulte https://en.wikipedia.org/wiki/Random_forest.
#
# A função que vamos utilizar para construir esse modelo também faz parte do `sklearn` e é chamada de `RandomForestClassifier`.

# %%
# construir as bases de treinamento e teste
(trainData, testData, trainLabels, testLabels) = train_test_split(np.array(data),
	np.array(labels), test_size=0.25, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# iniciar o modelo como árvore de decisão
model = RandomForestClassifier(random_state=84)
# treinar o modelo
print("[INFO] treinando modelo...")
model.fit(trainData, trainLabels)
# Out:
# [INFO] treinando modelo...
# RandomForestClassifier(random_state=84)

# %%
print("[INFO] avaliando...")
predictions = model.predict(testData)
print(classification_report(testLabels, predictions))
# Out:
# [INFO] avaliando...
#               precision    recall  f1-score   support
#
#        coast       0.81      0.91      0.86        87
#       forest       0.95      0.90      0.92        77
#      highway       0.87      0.72      0.79        57
#       street       0.87      0.91      0.89        89
#
#     accuracy                           0.87       310
#    macro avg       0.88      0.86      0.86       310
# weighted avg       0.87      0.87      0.87       310

# %% [markdown]
# Note que o desempenho já foi consideravelmente superior ao de uma árvore de decisão simples.
